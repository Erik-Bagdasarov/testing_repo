# %%
from time import process_time_ns
from xml.sax.handler import property_interning_dict

import pandas as pd
from IPython.core.events import pre_run_cell

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#      name  temp  feels_like  min_temp  max_temp
# 0  Moscow -0.76       -3.74     -0.76     -0.71

# %%
df_2 = pd.read_csv('data_2.csv')
df_2['body'] = df_2['body'].replace('\n', '', regex=True)
df_2
# Out:
#     userId   id                                              title  \
# 0        1    1  sunt aut facere repellat provident occaecati e...
# 1        1    2                                       qui est esse
# 2        1    3  ea molestias quasi exercitationem repellat qui...
# 3        1    4                               eum et est occaecati
# 4        1    5                                 nesciunt quas odio
# ..     ...  ...                                                ...
# 95      10   96  quaerat velit veniam amet cupiditate aut numqu...
# 96      10   97         quas fugiat ut perspiciatis vero provident
# 97      10   98                        laboriosam dolor voluptates
# 98      10   99  temporibus sit alias delectus eligendi possimu...
# 99      10  100              at nam consequatur ea labore ea harum
#
#                                                  body
# 0   quia et suscipitsuscipit recusandae consequunt...
# ...

# %%
df_2.to_json('data_2.json', indent=4)

# %%
df_json = pd.read_json('data_2.json')
df_json
# Out:
#     userId   id                                              title  \
# 0        1    1  sunt aut facere repellat provident occaecati e...
# 1        1    2                                       qui est esse
# 2        1    3  ea molestias quasi exercitationem repellat qui...
# 3        1    4                               eum et est occaecati
# 4        1    5                                 nesciunt quas odio
# ..     ...  ...                                                ...
# 95      10   96  quaerat velit veniam amet cupiditate aut numqu...
# 96      10   97         quas fugiat ut perspiciatis vero provident
# 97      10   98                        laboriosam dolor voluptates
# 98      10   99  temporibus sit alias delectus eligendi possimu...
# 99      10  100              at nam consequatur ea labore ea harum
#
#                                                  body
# 0   quia et suscipitsuscipit recusandae consequunt...
# ...

# %%
df_js = pd.read_json('my.json')
# Out:
#                                                 response
# count                                             594384
# item   [{'user_id': '1', 'email': 'test_1@test.com', ...

# %%
import json

with open('my.json', 'r') as file:
    data = json.load(file)
    json_data = json.dumps(data, indent=4)

if 'item' in data:
    df = pd.DataFrame(data['response']['item'][0])
    print(df)

# %%
print(json_data)
# Out:
# {
#     "response": {
#         "count": 594384,
#         "item": [
#             {
#                 "user_id": "1",
#                 "email": "test_1@test.com",
#                 "name": "test_1",
#                 "given_name": "Hello_test_1",
#                 "family_name": "Test_test_1",
#                 "nickname": "test_1",
#                 "last_ip": "94.121.163.63",
#                 "logins_count": 15,
#                 "created_at": "2016-11-28T14:10:11.338Z",
#                 "updated_at": "2016-12-02T01:17:29.310Z",
#                 "last_login": "2016-12-02T01:17:29.310Z",
#                 "likes": 504,
#                 "dislikes": 532
#             },
#             {
#                 "user_id": "2",
#                 "email": "test_2@test.com",
#                 "name": "test_2",
#                 "given_name": "Hello_test_2",
#                 "family_name": "Test_test_2",
#                 "nickname": "test_2",
#                 "last_ip": "94.121.168.53",
# ...

# %%
df_rows = []

for i in data['response']['item']:
    df_rows.append(i)

df = pd.DataFrame(df_rows)
df.head()
# Out:
#   user_id              email         name    given_name  family_name nickname  \
# 0       1    test_1@test.com       test_1  Hello_test_1  Test_test_1   test_1
# 1       2    test_2@test.com       test_2  Hello_test_2  Test_test_2   test_2
# 2       3        aaa@aaa.com  aaa@aaa.com          John        Dough      aaa
# 3       4            a@a.com      a@a.com          Jane        Dough        a
# 4       5  test9999@test.com          NaN         Dummy         User      NaN
#
#          last_ip  logins_count                created_at  \
# 0  94.121.163.63          15.0  2016-11-28T14:10:11.338Z
# 1  94.121.168.53           1.0  2016-11-28T16:00:04.209Z
# 2  94.121.168.53           2.0  2016-11-28T16:12:23.777Z
# 3  94.121.163.63           3.0  2016-12-01T23:59:16.473Z
# 4            NaN           NaN  2016-12-09T12:01:23.787Z
#
#                  updated_at                last_login  likes  dislikes
# 0  2016-12-02T01:17:29.310Z  2016-12-02T01:17:29.310Z    504       532
# ...

# %%
print(json_data['response'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 print(json_data['response'])
#
# TypeError: string indices must be integers, not 'str'
